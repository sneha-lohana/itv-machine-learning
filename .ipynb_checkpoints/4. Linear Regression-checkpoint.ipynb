# %% [markdown]
# # Linear Regression
#
# There are two techniques in which we can achieve Linear Regression
#
#     1. Ordinary Least Square (OLS)
#     2. Gradient Descent

# %% [markdown]
# ### Ordinary Least Square(OLS)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sci kit
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#axis = 1 column, inplace=True
df.drop("Unnamed: 0",axis=1,inplace=True)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.scatterplot(data=df,x="TV", y="sales")
plt.show()

# %%
sns.scatterplot(data=df,x="radio", y="sales")
plt.show()

# %%
sns.scatterplot(data=df,x="newspaper", y="sales")
plt.show()

# %%
cor = df.corr()
cor
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(cor,annot=True)
plt.show()

# %% [markdown]
# # Find the model that will return the best investment return

# %% [markdown]
# # Modeling with TV

# %%
#In linear regression model it expects a 2 dimensional 
# array input for x axis, therefore we write a axis 
# columns in double square brakects
x_tv = df[["TV"]] 
x_radio = df[["radio"]]
x_news = df[["newspaper"]]
y = df["sales"]

# %%
# spliting data for training and testing
x_train, x_test, y_train, y_test = train_test_split(x_tv, y,
                                            random_state=1, 
                                             test_size=0.3)
#random state - if random state is not mentioned random data 
# will be picked for every split
#test_size means the percentage of data to be kept for 
# testing

# %%
#create object of the LinearRegression
lr = LinearRegression()

# %%
#fit method will find the slope(theta 1) and intercept 
# (theta 0)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#return the value of intercept(theta 0)
lr.intercept_
# Out:
# 6.923519536059554

# %%
#returns the value of slope( theta 1)
lr.coef_
# Out:
# array([0.04812204])

# %%
#Testing 
#predict function will be predict y hat 
# (yhat=theta0+theta1 * x)
y_pred = lr.predict(x_test)

# %%
print(y_pred, y_test)
# Out:
# [17.06764591 16.66823297 11.52879892 20.4073156  19.1368937  20.57093054
#  14.78184893 15.62398466 10.32093567 17.2890073  14.83959538 10.25356482
#  17.25532187 12.20731971 17.78947654 12.97246017 13.26119242 20.91259704
#   8.1554438  17.06283371 11.75497252 10.18619396  8.13138278 12.09182681
#  12.35649804 15.98971218  8.99757953 18.89628349 14.95027608 18.47762173
#  18.46799732 18.2081383  14.12738917 15.11389102 18.87703468 15.82128503
#  17.62586159 13.15051172 17.35637816  7.86671155  7.55391828 11.2737521
#   7.82340171 16.74522823  7.27481044 14.01189627 10.68666319 17.89534503
#  16.78853807 17.96752809 20.864475   12.84734286  7.85708714 15.71060434
#  19.70473379 14.89252963 17.43818563  8.12657058 18.0926454   8.99276733] 58     23.8
# 40     16.6
# 34      9.5
# 102    14.8
# 184    17.6
# 198    25.5
# 95     16.9
# 4      12.9
# 29     10.5
# 168    17.1
# 171    14.5
# 18     11.3
# 11     17.4
# 89     16.7
# 110    13.4
# 118    15.9
# 159    12.9
# 35     12.8
# ...

# %%
# MSE = sum(y-y_hat)2
mean_squared_error(y_test, y_pred)
# Out:
# 10.571057434656955

# %%
r2_score(y_test, y_pred)
# Out:
# 0.575061860494331

# %%
sns.scatterplot(data=df, x="TV", y="sales")
sns.lineplot(x_test['TV'].to_list(), y_pred, color="red")
plt.show()

# %% [markdown]
# # Modeling with Radio

# %%
x_train, x_test, y_train, y_test = train_test_split(x_radio, 
                            y, random_state=1, test_size=0.3)
lr = LinearRegression()
#fit method will find the slope(theta 1) and intercept (theta 0)
lr.fit(x_train,y_train)
#return the value of intercept(theta 0)
lr.intercept_
#returns the value of slope( theta 1)
print(lr.coef_)
#predict function will be predict y hat (yhat=theta0+theta1 * x)
y_pred = lr.predict(x_test)
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:",r2_score( y_test, y_pred))
sns.scatterplot(data=df, x="radio", y="sales")
sns.lineplot(x_test['radio'].to_list(), y_pred)
plt.show()
# Out:
# [0.1874808]
# MSE: 14.604130559272193
# R2: 0.41293932917162335

# %% [markdown]
# # Modeling with Newspaper

# %%
x_train, x_test, y_train, y_test = train_test_split(x_news, y, random_state=1, test_size=0.3)
lr = LinearRegression()
#fit method will find the slope(theta 1) and intercept (theta 0)
lr.fit(x_train,y_train)
#return the value of intercept(theta 0)
lr.intercept_
#returns the value of slope( theta 1)
print(lr.coef_)
#predict function will be predict y hat (yhat=theta0+theta1 * x)
y_pred = lr.predict(x_test)
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:",r2_score( y_test, y_pred))
sns.scatterplot(data=df, x="newspaper", y="sales")
sns.lineplot(x_test['newspaper'].to_list(), y_pred)
plt.show()
# Out:
# [0.06532045]
# MSE: 25.497452374414927
# R2: -0.024953278429509007

# %% [markdown]
# # Multiple Linear Regression

# %%
### Computing with 3 parameters 
#     x1 = TV
#     x2 = radio
#     x3 = newspaper
x_trn = df [['TV', 'radio', 'newspaper']]
x_train, x_test, y_train, y_test = train_test_split(x_trn, y, 
                                random_state=12, test_size=0.3)
lr = LinearRegression()
lr.fit(x_train, y_train)
print(lr.intercept_)
print(lr.coef_)
y_hat = lr.predict(x_test)
print("MSE=",mean_squared_error(y_test, y_hat))
print("R2=", r2_score(y_test, y_hat))
# Out:
# 2.8687002733924096
# [ 0.04510023  0.19513748 -0.00336377]
# MSE= 2.5610276048471907
# R2= 0.9137053125897675

# %%
### Computing with 2 parameters 
#     x1 = TV
#     x2 = newspaper

x_tn = df[['TV', 'newspaper']]
x_train, x_test, y_train, y_test = train_test_split(x_tn, y, random_state=1, 
                                                    test_size=0.3)
lr = LinearRegression()
lr.fit(x_train, y_train)
y_hat = lr.predict(x_test)
print(mean_squared_error(y_test, y_hat))
print(r2_score(y_test, y_hat))
# Out:
# 10.604482538249783
# 0.5737182294128316

# %%
### Computing with 2 parameters 
#     x1 = newspaper
#     x2 = radio
x_rn = df[['radio', 'newspaper']]
x_train, x_test, y_train, y_test = train_test_split(x_rn, y, random_state=1, 
                                                    test_size=0.3)
lr = LinearRegression()
lr.fit(x_train, y_train)
y_hat = lr.predict(x_test)
print(mean_squared_error(y_test, y_hat))
print(r2_score(y_test, y_hat))
# Out:
# 14.777047324313644
# 0.40598837569509094

# %%
### Computing with 2 parameters 
#     x1 = TV
#     x2 = radio
x_tr = df[['TV', 'radio']]
x_train, x_test, y_train, y_test = train_test_split(x_tr, y, random_state=1, 
                                                    test_size=0.3)
lr = LinearRegression()
lr.fit(x_train, y_train)
y_hat = lr.predict(x_test)
print(mean_squared_error(y_test, y_hat))
print(r2_score(y_test, y_hat))
# We get best output with Multiple Linear Regression on indepent variables - TV and radio
# Out:
# 1.9147050289721788
# 0.9230321850256801

# %% [markdown]
# # Assumption of Linear Regression
# ### Linear Regression will work best if all the assumption are satisfied
#
#     1. Must have linear corelation - (PLease note if the data is not linear you will plot Polynomial regression)
#     2. There should be little or no variance among residuals (Homoskedestic)
#     3. There should be no multicolinearity (or any column that is dependent on the other column)
#     4. Resudials must be normally distributed(bell curve)
#
# ##### You can use linear regression if Test 2, 3 or 4 fails but you can't use linear regression if Test 1 fails

# %%
#Test 2: Check if data is homoskedestical
residuals = y_test - y_hat
sns.scatterplot(y_hat, residuals)
plt.show()
#if you observe the plot the data is hetroskedestical
# Test 2 fails

# %%
# Test 3: There should be no multicolinearity (or any column that is dependent on the other column)
fig, axes = plt.subplots(1,3, figsize=(16, 6))
sns.scatterplot(data=df, x="TV", y="sales",ax=axes[0])
sns.scatterplot(data=df, x="radio", y="sales", ax=axes[1])
sns.scatterplot(data=df, x="radio", y="TV", ax=axes[2])
plt.show()
# Test 3 passes there is no multicolinearity in the all the 3 columns of TV, radio and sales

# %%
# Test 4 Resudials must be normally distributed(bell curve)
sns.distplot(residuals)
plt.show()
# there is negative skewness in the output therefore Test 4 fails

# %% [markdown]
# # Polynomial Regression
# When a straight line is unable to capture the patterns in the data.

# %%
from sklearn.preprocessing import PolynomialFeatures
x = df[["TV","radio"]]
y = df["sales"]

# %%
# Here the parameter passed in the PolynomialFeature is the degree
pf = PolynomialFeatures(2)
# Degree formula will be like
# y = TV x theta + TV * TV x theta + Radio x theta + Radio x radio x theta
x_poly = pf.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_poly, 
                        y, random_state=1,test_size=0.3)

# %%
lr= LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(x_test)
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.17238345081004028
# 0.9930704848288281

# %%
# Check if data is homoskedestical
residuals = y_test - y_pred
sns.scatterplot(y_pred, residuals)
plt.show()
# Resudials must be normally distributed(bell curve)
sns.distplot(residuals)
plt.show()

# %%
pf = PolynomialFeatures(3)
x_poly = pf.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_poly, y, random_state=1,test_size=0.3)
lr= LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(x_test)
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.14469078645956274
# 0.9941836818140669

# %%
# Check if data is homoskedestical
residuals = y_test - y_pred
sns.scatterplot(y_pred, residuals)
plt.show()
# Resudials must be normally distributed(bell curve)
sns.distplot(residuals)
plt.show()
