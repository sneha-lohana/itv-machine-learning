# %%
# Matplotlib is a visualization library in Python for 2D plots of arrays
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Line Plot
#     Line plot is very basic matplotlib plot which is used to draw line chart.
#     Line always contains two parameter x and y

# %%
#visualization can possible with 1 dimension or 2 dimensional array
x = [1,3,5,7,9,11]
y = [11,14,15,19,24,25]
# In this the object name of the matplotlib will be visible
plt.plot(x,y)

# %%
# to avoid the object name use show function
plt.figure(figsize=(7,7))
plt.plot(x,y)
plt.show()

# %%
# 1 dimension plotting
plt.plot(x)
plt.show()

# %%
# Creating wave line using sin wave in matplot
x = np.arange(0, 10, 0.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### Understanding different attributes of matplotlib, which are commonly used across all graphs
#     Figsize: to give size to chart area
#     Labels: to assign label to data (xlabel,ylabel)
#     Title : to give title of chart
#     Limits: to start and end point to each axis (xlim, ylim)
#     Ticks: used to rotate the characters visible on x and y axis (xticks, yticks)
#     Legend : gives label to plots
#     Color : used to give colors to plot (function parameter of plot)
# Note: Multiple Plots: multiple line in one chart called multiple plot

# %%
area = [600,800, 1000, 1200, 1500]
price = [15,18,25,35,40]
#increase size of the plot
#plt.figure(figsize=(width, height))
plt.figure(figsize=(7,7))
plt.plot(area,price)
#add information of the graph
#add title
plt.title("Area vs Price")
#add label for x and y
plt.xlabel("Area")
plt.ylabel("Price")
#adding limit to the plot
plt.xlim((400, 2000))
plt.ylim((5,50))
plt.show()

# %%
plt.plot(area,price,'go-')
#add information of the graph
plt.title("Area vs Price")
plt.xlabel("Area")
plt.ylabel("Price")
#rotate ticks
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#Multiple plots
x = np.arange(1,20)
y1 = np.sqrt(x)
y2 = np.log(x)
plt.figure(figsize=(6,6))
#changing the color of the lines
plt.plot(x,y1,color="yellow")
plt.plot(x,y2,color="red")
#legend in 2 line ploting
plt.legend(labels=['sqrt','log'])
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,x,color="blue")
plt.plot(x,y1,color="yellow")
plt.plot(x,y2,color="red")
plt.legend(labels=['linear','sqrt','log'])
plt.show()

# %% [markdown]
# ### Histograms plots:
# This is used for continuous data. Hist is used to define histogram type plot.
#
# More attributes of matplotlib:
#
#     axvline : gives verticle line on x axis
#     bins:  define number of bins size required in plot (function parameter of hist)

# %%
df = pd.read_csv("cars.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# width                205 non-null float64
# height               205 non-null float64
# engine-type          205 non-null object
# engine-size          205 non-null int64
# horsepower           205 non-null object
# city-mpg             205 non-null int64
# highway-mpg          205 non-null int64
# price                205 non-null int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.1+ KB

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
# before make graph write down your intution using describe functions. Is the data normally distrubutted?
plt.figure(figsize=(7,7))
plt.title("width frequency distribution")
plt.ylabel("freqeuncy")
plt.xlabel("width")
#bins are no of bars in histogram
plt.hist(df['width'],bins=10)
plt.show()
#graph is normally distributed

# %%
# panda is made from numpy and matplotlib so all stuff we perform with matplotlib is possible with panda as well
df['width'].hist(bins=15)
plt.show()

# %%
#show mean & median plot in graph
width_mean=df["width"].mean()
width_median=df["width"].median()

# %%
plt.figure(figsize=(7,7))
plt.hist(df['width'],bins=10)
plt.axvline(width_mean,color="red")
plt.axvline(width_median,color="green")
plt.title("width frequency distribution")
plt.ylabel("freqeuncy")
plt.xlabel("width")
plt.show()

# %%
#above same plot using pandas
plt.figure(figsize=(7,7))
df['width'].hist(bins=10)
plt.axvline(width_mean,color="red")
plt.axvline(width_median,color="green")
plt.title("width frequency distribution")
plt.ylabel("freqeuncy")
plt.xlabel("width")
plt.show()

# %% [markdown]
# ### Bar plot
# Majorly used for catogorial data
#
#     Kind : type of plot specify bar in kind will give bar plot(bar, barh)

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
#here the kind accepts bar this will create vertical bars
plt.figure(figsize=(9,9))
df["make"].value_counts().plot(kind="bar")
plt.title("Make vs Count")
plt.xlabel("Make")
plt.ylabel("Count")
plt.show()

# %%
#here the kind accepts barh this will create horizontal bars
plt.figure(figsize=(9,9))
df["make"].value_counts().plot(kind="barh")
plt.title("Make vs Count")
plt.xlabel("Make")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Pie chart
# Used to define percentage based data. Pie function used to make pie plot
#
#     Autopct : used to give percentage distribution over data
#     Explode : used to extract pie out of plot

# %%
df["body-style"].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot(kind="pie")
plt.show()

# %%
#Pie using Pandas
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot.pie()
plt.show()

# %%
#this will display the percentage on pie using pandas
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
#this will display the percentage on pie using matplotlib
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot(kind="pie", autopct="%1.2f%%")
plt.show()

# %%
#this is to remove a part of sector away from the pie chart.
#with use of explode attribute it is possible
#the parameters in explode moves from top anticlockwise
# using pandas
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot.pie(autopct="%1.1f%%",
                                         explode=(0,0,0,0,0.2))
plt.show()

# %%
#using matplotlib
plt.figure(figsize=(7,7))
df["body-style"].value_counts().plot(kind="pie", autopct="%1.2f%%", 
                                     explode=(0,0,0,0.1,0))
plt.show()

# %% [markdown]
# ### Scatter plot
# Mostly used to check correlation of data in linear regression

# %%
x=[1,2,3,4]
y=[12,14,15,18]
plt.scatter(x,y)
plt.show()

# %%
#this function displays corelation between all columns
df.corr()
# Out:
#              symboling     width    height  engine-size  city-mpg  \
# symboling     1.000000 -0.232919 -0.541038    -0.105790 -0.035823
# width        -0.232919  1.000000  0.279210     0.735433 -0.642704
# height       -0.541038  0.279210  1.000000     0.067149 -0.048640
# engine-size  -0.105790  0.735433  0.067149     1.000000 -0.653658
# city-mpg     -0.035823 -0.642704 -0.048640    -0.653658  1.000000
# highway-mpg   0.034606 -0.677218 -0.107358    -0.677470  0.971337
# price        -0.085781  0.718253  0.132444     0.852995 -0.654611
#
#              highway-mpg     price
# symboling       0.034606 -0.085781
# width          -0.677218  0.718253
# height         -0.107358  0.132444
# engine-size    -0.677470  0.852995
# city-mpg        0.971337 -0.654611
# highway-mpg     1.000000 -0.679048
# price          -0.679048  1.000000

# %%
plt.figure(figsize=(7,7))
plt.scatter(x=df["width"], y=df["price"])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.scatter(x=df["height"], y=df["price"], color="brown")
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.scatter(df["city-mpg"], df["price"])
plt.show()

# %%
#correlation is good if price increases when engine size increases. 
# It is positively correlated
plt.scatter(df["engine-size"],df["price"])
plt.show()

# %%
#negatively correlated
plt.scatter(df["highway-mpg"],df["price"])
plt.show()

# %%
#above both are good for predictions 
#worst situation (no correlation)
plt.scatter(df["symboling"],df["price"])
plt.show()

# %%
df['size'] = df['width'] * df['height']

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price     size
# 0        111        21           27  13495  3128.08
# ...

# %%
plt.scatter(df["size"],df["price"])
plt.show()
